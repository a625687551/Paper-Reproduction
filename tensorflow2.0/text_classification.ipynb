# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.0.0-rc0'

# %%
imdb = keras.datasets.imdb
(train_data, train_label), (test_data, test_label) = imdb.load_data(num_words=10000)

# %%
print("Training entries: {}, labels: {}".format(len(train_data), len(train_label)))
# Out:
# Training entries: 25000, labels: 25000

# %%
print(train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
word_index = imdb.get_word_index()

# %%
word_index = {k:(v+3) for k,v in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2  # unknown
word_index["<UNUSED>"] = 3
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# %%
decode_review(train_data[0])
# Out:
# "<START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data,
                                                       value=word_index["<PAD>"],
                                                       padding="post",
                                                       maxlen=256)
test_data = keras.preprocessing.sequence.pad_sequences(test_data,
                                                       value=word_index["<PAD>"],
                                                       padding="post",
                                                       maxlen=256)

# %%
len(train_data[0])
# Out:
# 256

# %%
vocab_size=10000

model = keras.Sequential([
    keras.layers.Embedding(vocab_size, 16),
    keras.layers.GlobalAveragePooling1D(),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])
model.compile(optimizer="adam",
             loss="binary_crossentropy",
             metrics=["accuracy"])

# %%
x_val = train_data[:10000]
partial_x_train = train_data[10000:]

y_val = train_label[:10000]
partial_y_train = train_label[10000:]

# %%
history = model.fit(partial_x_train,
                   partial_y_train,
                   epochs=40,
                   batch_size=512,
                   validation_data=(x_val, y_val),
                   verbose=1)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/40
# WARNING:tensorflow:From C:\Anaconda3\envs\tf2.0\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 15000/15000 [==============================] - 1s 91us/sample - loss: 0.6923 - accuracy: 0.5345 - val_loss: 0.6909 - val_accuracy: 0.5965
# Epoch 2/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.6886 - accuracy: 0.6111 - val_loss: 0.6859 - val_accuracy: 0.6999
# Epoch 3/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.6806 - accuracy: 0.6895 - val_loss: 0.6749 - val_accuracy: 0.6750
# Epoch 4/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.6649 - accuracy: 0.7201 - val_loss: 0.6559 - val_accuracy: 0.7114
# Epoch 5/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.6392 - accuracy: 0.7595 - val_loss: 0.6272 - val_accuracy: 0.7682
# Epoch 6/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.6028 - accuracy: 0.7959 - val_loss: 0.5899 - val_accuracy: 0.7894
# Epoch 7/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.5593 - accuracy: 0.8159 - val_loss: 0.5484 - val_accuracy: 0.8141
# Epoch 8/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.5123 - accuracy: 0.8414 - val_loss: 0.5060 - val_accuracy: 0.8250
# Epoch 9/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.4664 - accuracy: 0.8576 - val_loss: 0.4664 - val_accuracy: 0.8405
# Epoch 10/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.4249 - accuracy: 0.8677 - val_loss: 0.4323 - val_accuracy: 0.8494
# Epoch 11/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.3886 - accuracy: 0.8781 - val_loss: 0.4039 - val_accuracy: 0.8553
# Epoch 12/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.3575 - accuracy: 0.8857 - val_loss: 0.3806 - val_accuracy: 0.8615
# Epoch 13/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.3315 - accuracy: 0.8921 - val_loss: 0.3620 - val_accuracy: 0.8663
# Epoch 14/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.3100 - accuracy: 0.8967 - val_loss: 0.3466 - val_accuracy: 0.8696
# Epoch 15/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.2901 - accuracy: 0.9026 - val_loss: 0.3345 - val_accuracy: 0.8734
# Epoch 16/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.2736 - accuracy: 0.9077 - val_loss: 0.3243 - val_accuracy: 0.8749
# Epoch 17/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.2587 - accuracy: 0.9121 - val_loss: 0.3160 - val_accuracy: 0.8764
# Epoch 18/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.2459 - accuracy: 0.9161 - val_loss: 0.3091 - val_accuracy: 0.8793
# Epoch 19/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.2338 - accuracy: 0.9201 - val_loss: 0.3033 - val_accuracy: 0.8803
# Epoch 20/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.2226 - accuracy: 0.9241 - val_loss: 0.2990 - val_accuracy: 0.8818
# Epoch 21/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.2127 - accuracy: 0.9280 - val_loss: 0.2961 - val_accuracy: 0.8803
# Epoch 22/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.2038 - accuracy: 0.9302 - val_loss: 0.2917 - val_accuracy: 0.8830
# Epoch 23/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.1951 - accuracy: 0.9341 - val_loss: 0.2893 - val_accuracy: 0.8834
# Epoch 24/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1869 - accuracy: 0.9374 - val_loss: 0.2875 - val_accuracy: 0.8847
# Epoch 25/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1796 - accuracy: 0.9402 - val_loss: 0.2864 - val_accuracy: 0.8842
# Epoch 26/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.1721 - accuracy: 0.9447 - val_loss: 0.2853 - val_accuracy: 0.8851
# Epoch 27/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1654 - accuracy: 0.9474 - val_loss: 0.2854 - val_accuracy: 0.8836
# Epoch 28/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.1588 - accuracy: 0.9503 - val_loss: 0.2843 - val_accuracy: 0.8856
# Epoch 29/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.1527 - accuracy: 0.9537 - val_loss: 0.2844 - val_accuracy: 0.8860
# Epoch 30/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1473 - accuracy: 0.9546 - val_loss: 0.2847 - val_accuracy: 0.8865
# Epoch 31/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1416 - accuracy: 0.9571 - val_loss: 0.2857 - val_accuracy: 0.8849
# Epoch 32/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1364 - accuracy: 0.9594 - val_loss: 0.2867 - val_accuracy: 0.8853
# Epoch 33/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.1315 - accuracy: 0.9613 - val_loss: 0.2878 - val_accuracy: 0.8859
# Epoch 34/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1267 - accuracy: 0.9633 - val_loss: 0.2902 - val_accuracy: 0.8851
# Epoch 35/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1227 - accuracy: 0.9652 - val_loss: 0.2920 - val_accuracy: 0.8850
# Epoch 36/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.1185 - accuracy: 0.9661 - val_loss: 0.2951 - val_accuracy: 0.8843
# Epoch 37/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1137 - accuracy: 0.9685 - val_loss: 0.2947 - val_accuracy: 0.8845
# Epoch 38/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1103 - accuracy: 0.9695 - val_loss: 0.2984 - val_accuracy: 0.8837
# Epoch 39/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1059 - accuracy: 0.9722 - val_loss: 0.2995 - val_accuracy: 0.8843
# Epoch 40/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.1025 - accuracy: 0.9725 - val_loss: 0.3027 - val_accuracy: 0.8831

# %%
results = model.evaluate(test_data, test_label)
print(results)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.32209212133407594, 0.87304]

# %%
history_dict = history.history

# %%
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
